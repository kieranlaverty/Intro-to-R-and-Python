# %% [markdown]
# This is a notebook to explain the difference between R and Python in creating a simple Data Analysis notebook

# %% [markdown]
# Import data

# %%
# Libraries 
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/lawre/OneDrive/Documents/Learning_R-main/Customers.csv")
print(df.head(10))
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
# 5           6  Female   22              58000                      76
# 6           7  Female   35              31000                       6
# 7           8  Female   23              84000                      94
# 8           9    Male   64              97000                       3
# 9          10  Female   30              98000                      72
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# ...

# %%
df = pd.DataFrame(df)
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
# Clean Data Drops any empty cells 
df = df.dropna()

print(df.to_string())
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)     Profession  Work Experience  Family Size
# 0              1    Male   19              15000                      39     Healthcare                1            4
# 1              2    Male   21              35000                      81       Engineer                3            3
# 2              3  Female   20              86000                       6       Engineer                1            1
# 3              4  Female   23              59000                      77         Lawyer                0            2
# 4              5  Female   31              38000                      40  Entertainment                2            6
# 5              6  Female   22              58000                      76         Artist                0            2
# 6              7  Female   35              31000                       6     Healthcare                1            3
# ...

# %%
# removes index code
df= df.dropna()
print(df)

# Drop a gender / any column 
#df = df.drop(columns=['Gender'])
#print(df)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
# Calcaute how much of Profession catagory count  
category_counts = df['Profession'].value_counts()
print(category_counts)
# Out:
# Profession
# Artist           612
# Healthcare       339
# Entertainment    234
# Engineer         179
# Doctor           161
# Executive        153
# Lawyer           142
# Marketing         85
# Homemaker         60
# Name: count, dtype: int64

# %%
# Create Pie chart with labels of entire data set
plt.figure(figsize=(8, 8))
category_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Customers by Country')
plt.ylabel('')  # Hides the default label
plt.show()

# %%
# Create Bar chart of all catagories 
plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
plt.title('Bar Chart of Customers by Country')
plt.ylabel('Number of Customers')
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\lawre\AppData\Local\Temp\ipykernel_6928\3815757500.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
# Histogram for Age Distribution
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Customers', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
# Box Plot for Annual Income
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Annual Income ($)'], color='lightgreen')
plt.title('Box Plot of Annual Income', fontsize=14)
plt.xlabel('Annual Income (k$)', fontsize=12)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.show()

# %%
# Density Plot for Annual Income
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Annual Income ($)'], shade=True, color='purple')
plt.title('Density Plot of Annual Income', fontsize=14)
plt.xlabel('Annual Income (k$)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.show()
# Out:
# C:\Users\lawre\AppData\Local\Temp\ipykernel_6928\3232715781.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Annual Income ($)'], shade=True, color='purple')

# %%
# Bar Plot for Average Spending Score by Profession
plt.figure(figsize=(12, 6))
sns.barplot(x='Profession', y='Spending Score (1-100)', data=df, estimator=lambda x: x.mean(), palette='coolwarm')
plt.title('Average Spending Score by Profession', fontsize=14)
plt.xlabel('Profession', fontsize=12)
plt.ylabel('Average Spending Score', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.show()
# Out:
# C:\Users\lawre\AppData\Local\Temp\ipykernel_6928\2632454413.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Profession', y='Spending Score (1-100)', data=df, estimator=lambda x: x.mean(), palette='coolwarm')

# %%
# Violin Plot for Spending Score by Profession
plt.figure(figsize=(12, 8))
sns.violinplot(x='Profession', y='Spending Score (1-100)', data=df, palette='muted')
plt.title('Spending Score by Profession', fontsize=14)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.show()
# Out:
# C:\Users\lawre\AppData\Local\Temp\ipykernel_6928\1039137768.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Profession', y='Spending Score (1-100)', data=df, palette='muted')

# %%
# Pair Plot
sns.pairplot(df[['Age', 'Annual Income ($)', 'Spending Score (1-100)']], diag_kind='kde', markers='o', palette='Set1')
plt.suptitle('Pairwise Relationships between Age, Income, and Spending Score', y=1.02, fontsize=16)
plt.show()
# Out:
# c:\Users\lawre\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\lawre\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\lawre\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\lawre\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 8))
correlation = df.select_dtypes(include=['number']).corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()
